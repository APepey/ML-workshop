# %%
import seaborn as sns
import pandas as pd

# %% [markdown]
# # A first look at our data

# %%
adults = pd.read_csv("../data/raw/adults.csv")
adults.head(10)
# Out:
#   Sample_number Site_code      LU Passage  Round  Day  Month  Year  Time  \
# 0        BC0001     FOL01  forest     low      1   17     10  2019    20
# 1        BC0002     FOL01  forest     low      1   17     10  2019    20
# 2        BC0003     FOL01  forest     low      1   17     10  2019    20
# 3        BC0004     FOL01  forest     low      1   17     10  2019    21
# 4        BC0005     FOL01  forest     low      1   17     10  2019    21
# 5        BC0006     FOL01  forest     low      1   17     10  2019    21
# 6        BC0007     FOL01  forest     low      1   17     10  2019    21
# 7        BC0008     FOL01  forest     low      1   17     10  2019    21
# 8        BC0009     FOL01  forest     low      1   17     10  2019    21
# 9        BC0010     FOL01  forest     low      1   17     10  2019    21
#
#   DayNb  ... Screen_bool Pos_bool PCR_species Molecular_marker  \
# 0  Day1  ...         0.0        0         NaN              NaN
# ...

# %%
adults.shape
# Out:
# (6692, 32)

# %%
adults.isna().sum()
# Out:
# Sample_number                                            0
# Site_code                                                0
# LU                                                       0
# Passage                                                  0
# Round                                                    0
# Day                                                      0
# Month                                                    0
# Year                                                     0
# Time                                                     0
# DayNb                                                    0
# DayNight                                                 0
# Season                                                   0
# Trap                                                     0
# Msq_genus                                                0
# Msq_group                                              315
# Msq_species                                              0
# ...

# %%
sns.scatterplot(data = adults,
            x = "Msq_species_complete",
            y = "LU",
            hue = "Screen")
# Out:
# <AxesSubplot:xlabel='Msq_species_complete', ylabel='LU'>
